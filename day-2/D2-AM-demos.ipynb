# %% [markdown]
# # Day 2 AM: Live demos

# %% [markdown]
# ## Day 2 AM – Agenda
#
# - Make sure we can all generate a wordcloud from yesterday
# - Building topic models
#   - Discussion: the opportunities and dangers of topic modelling
# - Hierarchical speech clustering
# - Comparison wordclouds
#   - Discussion: What questions are we trying to ask that this wordcloud answers? Is a wordcloud appropriate?
# - Lexical dispersion plots
#   - Discussion: How Brian has used them (and advanced versions of them) in research

# %% [markdown]
# ## Brian's Research
#
# - "Natural Language Processing"
#   - Lexical Dispersion Plots looking at RWE content online
#     - (There is a strategic overlap of screenshots there, major content warnings if you look at the reports)
#   - https://zenodo.org/record/4071472 and https://zenodo.org/record/5732611
#   - Topic Modelling: "latent dirichlet allocation" for MRes thesis supervision
#
# <div class="side-by-side">
#
# ![Lexical Dispersion Plot on Racial Superiority across 23,836 Gab accounts posting 1,357,391 times, 2019-Jan to Oct, with a term-frequency colour scale.](img/p59-i3.png)
# ![Table 1: Topics from the whole magazine corpus — eight topics with their top terms (Kathryn Elliott).](img/p59-i4.png)
#
# </div>

# %% [markdown]
# ## Brian: “AI” (Large Language Models) for data analysis
#
# - BERTopic
# - Sentiment analysis with LLM
# - Generative AI “summarisation”

# %% [markdown]
# ## Before we end, sticky note feedback
#
# - On the green sticky note, write one thing that went well this session.
# - On the red sticky note, write one thing that we can improve on, tomorrow.
